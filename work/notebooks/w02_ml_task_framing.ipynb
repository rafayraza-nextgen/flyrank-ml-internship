# %% [markdown]
# <a href="https://colab.research.google.com/github/rafayraza-nextgen/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rafayraza-nextgen/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# This is a Classification task that we will use for Ranking. First, the model will classify whether a webpage is declining (1) or stable (0). Then, we will use the model's probability scores to rank the pages from highest risk to lowest risk. This ordered list is exactly what the content strategist needs to do their job.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# I am predicting the is_declining_label. This label comes from a defined rule already present in the data pipeline: if the text in the trend_direction column is "down", the page is marked as a 1 (declining).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# My success metric is Recall. Missing a genuinely declining page (a false negative) costs the client weeks of lost traffic and is very expensive to fix later. Recall measures how well we successfully find the true declining pages. A "good" model for this business problem will have a high recall score, even if it means we get a few extra false positives.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row = One webpage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os, sys, subprocess
import pandas as pd

# 1. Download the folder if we are in Google Colab
IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    # Clone the repo if it is missing
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

    # Change into the folder if we are not already inside it
    if os.path.basename(os.getcwd()) != REPO_DIR:
        os.chdir(REPO_DIR)

# 2. Now load the dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# 3. Create the target label
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)

# 4. Show that one row equals one webpage
print("Shape of the data:", df.shape)
print("\nHere are the first 3 rows. Each row represents a single webpage URL:")
display(df.head(3))
# Out:
# Shape of the data: (30000, 45)
#
# Here are the first 3 rows. Each row represents a single webpage URL:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
#
#    char_count  ...   ctr avg_position  engagement_rate  scroll_rate  \
# 0     20457.0  ...  0.76         10.6             5.88         4.55
# 1     15562.0  ...  0.05         20.3             0.00        10.00
# 2     23643.0  ...  0.09         36.5             0.00        28.57
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A simple if-statement rule does not work well here. We already saw that the median "days since last update" is exactly 20 days for both declining and stable pages. The pattern is too messy. Machine Learning is better because it can look at many different signals at the same time—like traffic drops, search position, and page age—to find hidden patterns that a fixed rule would easily miss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
